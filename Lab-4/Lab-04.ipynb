# %%
#3q)
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

X = np.random.uniform(1, 10, 20)
Y = np.random.uniform(1, 10, 20)

classes = np.random.choice(['class0', 'class1'], size=20)

X_class0 = X[classes == 'class0']
Y_class0 = Y[classes == 'class0']
X_class1 = X[classes == 'class1']
Y_class1 = Y[classes == 'class1']

plt.figure(figsize=(8, 6))
plt.scatter(X_class0, Y_class0, c='blue', label='class0 (Blue)')
plt.scatter(X_class1, Y_class1, c='red', label='class1 (Red)')

# Add labels and title
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter Plot of Training Data')

plt.legend(loc='best')

plt.show()
